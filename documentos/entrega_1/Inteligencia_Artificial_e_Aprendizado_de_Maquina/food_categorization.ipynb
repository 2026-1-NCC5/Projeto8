# %%
# !pip install ultralytics roboflow

# %%
# !pip install roboflow

from roboflow import Roboflow

rf = Roboflow(api_key="TadbagVLz73yXH0tRlyT")
project = rf.workspace("rodrigo-reis-s-workspace").project("first-deliver-model-version")
dataset = project.version(1).download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
import yaml

caminho_yaml = "/content/first-deliver-model-version-1/data.yaml"

with open(caminho_yaml, "r") as f:
  dados = yaml.safe_load(f)

dados['train'] = '/content/first-deliver-model-version-1/train/images'
dados['val'] = '/content/first-deliver-model-version-1/test/images'

if 'test' in dados:
  dados['test'] = '/content/first-deliver-model-version-1/test/images'

with open(caminho_yaml, 'w') as f:
  yaml.dump(dados, f)

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')

resultados = model.train(data="/content/first-deliver-model-version-1/data.yaml", epochs=50, imgsz=640)
# Out:
# Ultralytics 8.4.32 🚀 Python-3.12.13 torch-2.10.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %%
from google.colab import files

arquivo_final = '/content/runs/detect/train/weights/best.pt'

files.download(arquivo_final)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_7334/1962946951.py in <cell line: 0>()
#       3 arquivo_final = '/content/runs/detect/train/weights/best.pt'
#       4
# ----> 5 files.download(arquivo_final)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/files.py in download(filename)
#     228   if not _os.path.exists(filename):
#     229     msg = 'Cannot find file: {}'.format(filename)
# --> 230     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     231
#     232   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: /content/runs/detect/train/weights/best.pt
